# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from os import chdir

chdir(r"C:\Users\rajku\Documents\Python-Data-Science")

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
custom_template = go.layout.Template(
    layout=go.Layout(
        font=dict(family="Comic Sans MS", size=14, color="blue"),
        title_font=dict(family="helvetica", size=24, color="red"),
        paper_bgcolor="#fffaaa",
        plot_bgcolor="#fffeee",
        xaxis=dict(showgrid=True,range=[0,10]),
        yaxis=dict(showgrid=True,range=[0,10]),
        autosize=True,
        height=1000,
        width=2000,
    )
)

fig = px.scatter(df,
                 x="sepal_length",
                 y="sepal_width",
                 color="species",
                 symbol="species",
                 labels={'sepal_width': 'Sepal Width (cm)', 'sepal_length': 'Sepal Length (cm)'},
                 title='Sepal Dimensions of Iris Species',
                 template=custom_template
                 )


fig.show()
