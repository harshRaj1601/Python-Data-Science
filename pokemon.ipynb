# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 6))
fig = sns.swarmplot(df,x="Generation",y="Total",hue="Legendary")
plt.show()

# %%
px.pie(df,names="Legendary",values="Speed")

# %%
sns.scatterplot(df,x="Attack",y="Total",hue="Legendary")
# Out:
# <Axes: xlabel='Attack', ylabel='Total'>

# %%
sns.scatterplot(df, x="HP", y="Total", hue="Legendary")
# Out:
# <Axes: xlabel='HP', ylabel='Total'>

# %%
px.histogram(df, x="Total",nbins=20)

# %%
px.histogram(df,x="HP")

# %%
px.histogram(df, x="Attack")

# %%
plt.figure(figsize=(15, 6))
sns.countplot(y="Type 1", data=df, order=df["Type 1"].value_counts().index)
plt.title("Distribution of Pokémon by Type 1")
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.countplot(y="Type 2", data=df, order=df["Type 2"].value_counts().index)
plt.title("Distribution of Pokémon by Type 2")
plt.show()

# %%
stats = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]

plt.figure(figsize=(15, 10))
for i, stat in enumerate(stats, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x="Legendary", y=stat, data=df)
    plt.title(f"{stat} Comparison by Legendary Status")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
for i, stat in enumerate(stats, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x="Generation", y=stat, data=df)
    plt.title(f"{stat} Comparison by Generation")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
type_combinations = df.groupby(["Type 1", "Type 2"]).size().unstack().fillna(0)
sns.heatmap(type_combinations, annot=True, fmt=".0f", cmap="Blues")
plt.title("Type Combinations Frequency")
plt.show()

# %%
plt.figure(figsize=(12, 8))
corr_matrix = df[stats].corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Matrix of Stats")
plt.show()

# %%
df1 = df.groupby(by="Generation")["Legendary"].sum()

# %%
df["Legendary"].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
px.bar(df1)

# %%
sns.countplot(df,x="Generation",hue="Legendary")
# Out:
# <Axes: xlabel='Generation', ylabel='count'>

# %%
sns.lineplot()

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df3 = df.groupby(by="Generation")[["HP", "Attack", "Defense", "Sp. Atk","Sp. Def","Speed"]].sum()
df3
# Out:
#                HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# Generation
# 1           10926   12722    11763    11922    11469  12049
# 2            7548    7635     7779     6990     7834   6552
# 3           10647   13060    11856    12129    11396  10708
# 4            8843   10027     9454     9245     9340   8632
# 5           11845   13541    11934    11878    11342  11233
# 6            5598    6216     6288     6092     6141   5448

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df3.T,dashes=False)
plt.show()

# %%
px.line(df3.T)
